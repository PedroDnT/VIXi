# %%
from B3_reader import *

FY86 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1986.TXT" 
FY87 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1987.TXT" 
FY88 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1988.TXT" 
FY89 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1989.TXT" 
FY90 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1990.TXT" 
FY91 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1991.TXT" 
FY92 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1992.TXT" 
FY93 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1993.TXT" 
FY94 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1994.TXT" 
FY95 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1995.TXT" 
FY96 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1996.TXT" 
FY97 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1997.TXT" 
FY98 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1998.TXT" 
FY99 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A1999.TXT" 
FY00 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2000.TXT" 
FY01 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2001.TXT" 
FY02 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2002.TXT" 
FY03 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2003.TXT" 
FY04 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2004.TXT" 
FY05 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2005.TXT" 
FY06 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2006.TXT" 
FY07 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2007.TXT" 
FY08 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2008.TXT" 
FY09 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2009.TXT" 
FY10 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2010.TXT" 
FY11 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2011.TXT" 
FY12 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2012.TXT" 
FY13 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2013.TXT" 
FY14 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2014.TXT" 
FY15 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2015.TXT" 
FY16 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2016.TXT" 
FY17 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2017.TXT" 
FY18 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2018.TXT" 
FY19 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2019.TXT" 
FY20 = "/Users/pedrotodescan/Documents/Coding/B3 New/Historical Data/COTAHIST_A2020.TXT" 


dataFY86 = parse_dataset(FY86)
print('Parsing 1986')
dataFY87 = parse_dataset(FY87)
print('Parsing 1987')
dataFY88 = parse_dataset(FY88)
print('Parsing 1988')
dataFY89 = parse_dataset(FY89)
print('Parsing 1989')
dataFY90 = parse_dataset(FY90)
print('Parsing 1990')
dataFY91 = parse_dataset(FY91)
print('Parsing 1991')
dataFY92 = parse_dataset(FY92)
print('Parsing 1992')
dataFY93 = parse_dataset(FY93)
print('Parsing 1993')
dataFY94 = parse_dataset(FY94)
print('Parsing 1994')
dataFY95 = parse_dataset(FY95)
print('Parsing 1995')
dataFY96 = parse_dataset(FY96)
print('Parsing 1996')
dataFY97 = parse_dataset(FY97)
print('Parsing 1997')
dataFY98 = parse_dataset(FY98)
print('Parsing 1998')
dataFY99 = parse_dataset(FY99)
print('Parsing 1999')
dataFY00 = parse_dataset(FY00)
print('Parsing 2000')
dataFY01 = parse_dataset(FY01)
print('Parsing 2001')
dataFY02 = parse_dataset(FY02)
print('Parsing 2002')
dataFY03 = parse_dataset(FY03)
print('Parsing 2003')
dataFY04 = parse_dataset(FY04)
print('Parsing 2004')
dataFY05 = parse_dataset(FY05)
print('Parsing 2005')
dataFY06 = parse_dataset(FY06)
print('Parsing 2006')
dataFY07 = parse_dataset(FY07)
print('Parsing 2007')
dataFY08 = parse_dataset(FY08)
print('Parsing 2008')
dataFY09 = parse_dataset(FY09)
print('Parsing 2009')
dataFY10 = parse_dataset(FY10)
print('Parsing 2010')
dataFY11 = parse_dataset(FY11)
print('Parsing 2011')
dataFY12 = parse_dataset(FY12)
print('Parsing 2012')
dataFY13 = parse_dataset(FY13)
print('Parsing 2013')
dataFY14 = parse_dataset(FY14)
print('Parsing 2014')
dataFY15 = parse_dataset(FY15)
print('Parsing 2015')
dataFY16 = parse_dataset(FY16)
print('Parsing 2016')
dataFY17 = parse_dataset(FY17)
print('Parsing 2017')
dataFY18 = parse_dataset(FY18)
print('Parsing 2018')
dataFY19 = parse_dataset(FY19)
print('Parsing 2019')
dataFY20 = parse_dataset(FY20)
print('Wrapping up')

print('Merging Dataframes')
df = dataFY86.append(dataFY87).append(dataFY88).append(dataFY89).append(dataFY90).append(dataFY91).append(dataFY92).append(dataFY93).append(dataFY94).append(dataFY95).append(dataFY96).append(dataFY97).append(dataFY98).append(dataFY99).append(dataFY00).append(dataFY01).append(dataFY02).append(dataFY03).append(dataFY04).append(dataFY05).append(dataFY06).append(dataFY07).append(dataFY08).append(dataFY09).append(dataFY10).append(dataFY11).append(dataFY12).append(dataFY13).append(dataFY14).append(dataFY15).append(dataFY16).append(dataFY17).append(dataFY18).append(dataFY19).append(dataFY20)

print('Adjusting Formats and droping shitty data')

print('Adjusting Formats and droping shitty data')


df.set_index(['Date','Ticker'], inplace=True)
df.sort_index(inplace=True)
pd.options.mode.chained_assignment = None
print('Data is ready FAM')
# Out:
# Parsing 1986
# Parsing 1987
# Parsing 1988
# Parsing 1989
# Parsing 1990
# Parsing 1991
# Parsing 1992
# Parsing 1993
# Parsing 1994
# Parsing 1995
# Parsing 1996
# Parsing 1997
# Parsing 1998
# Parsing 1999
# Parsing 2000
# Parsing 2001
# Parsing 2002
# Parsing 2003
# Parsing 2004
# Parsing 2005
# Parsing 2006
# Parsing 2007
# Parsing 2008
# Parsing 2009
# Parsing 2010
# Parsing 2011
# Parsing 2012
# Parsing 2013
# Parsing 2014
# Parsing 2015
# Parsing 2016
# Parsing 2017
# Parsing 2018
# Parsing 2019
# Wrapping up
# Merging Dataframes
# Adjusting Formats and droping shitty data
# Adjusting Formats and droping shitty data
# Data is ready FAM

# %%
df.head()
df.tail()
# Out:
#                     MarketType   FirmName  OpenPrice  HighPrice  LowPrice  \
# Date       Ticker
# 2020-04-22 IBOVT60  PUT OPTION      IBOVE     1732.0     1866.0    1732.0
#            IBOVV50  PUT OPTION      IBOVE     1220.0     1220.0    1210.0
#            IBOVV68  PUT OPTION  IBOVE  FM     4283.0     4283.0    4283.0
#            IBOVV69  PUT OPTION  IBOVE  FM     4539.0     4539.0    4539.0
#            IBOVX10  PUT OPTION      IBOVE    21000.0    21000.0   20500.0
#
#                     AvgPrice  ClosePrice     Volume  ExecutionPrice(Futures)  \
# Date       Ticker
# 2020-04-22 IBOVT60   1752.71      1866.0  1919220.0                  60000.0
#            IBOVV50   1215.83      1220.0  1459000.0                  50000.0
#            IBOVV68   4283.00      4283.0   214150.0                  68000.0
#            IBOVV69   4539.00      4539.0   226950.0                  69000.0
#            IBOVX10  20750.00     20500.0   415000.0                 100000.0
#
# ...

# %%
is_call =df['BDICode']=='OPCOES DE COMPRA DE INDICES'
is_put = df['BDICode']=='OPCOES DE VENDA DE INDICES'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BDICode'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-cd65b28e09af> in <module>
# ...

# %%
df.columns
# Out:
# Index(['RecordType', 'BDICode', 'MarketType', 'FirmName', 'Especs',
#        'DaysDue(fut)', 'Currency', 'OpenPrice', 'HighPrice', 'LowPrice',
#        'AvgPrice', 'ClosePrice', 'BestBid', 'BestAsk', '#Trades',
#        '#BondTrades', 'Volume', 'ExecutionPrice(Futures)', 'Adjust',
#        'ExpiringDate', 'LoteSize', 'IsinCode'],
#       dtype='object')

# %%
df=df[is_call | is_put]

# %%
df=df.drop(['Adjust','BDICode','RecordType','Especs','DaysDue(fut)','#BondTrades','BestBid','BestAsk','LoteSize'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-19d56bf12855> in <module>
# ----> 1 df=df.drop(['Adjust','BDICode','RecordType','Especs','DaysDue(fut)','#BondTrades','#Trades','BestBid','BestAsk','LoteSize'], axis=1)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
df
# Out:
#                      MarketType   FirmName Currency  OpenPrice  HighPrice  \
# Date       Ticker
# 1996-07-15 OIB 6    CALL OPTION       IBOV       R$     2850.0     3000.0
#            OIB 8    CALL OPTION       IBOV       R$     1400.0     1400.0
# 1996-07-16 OIB 5    CALL OPTION       IBOV       R$     2600.0     2600.0
#            OIB 6    CALL OPTION       IBOV       R$     1700.0     1850.0
#            OIB 8    CALL OPTION       IBOV       R$      650.0      650.0
# ...                         ...        ...      ...        ...        ...
# 2020-04-22 IBOVT60   PUT OPTION      IBOVE       R$     1732.0     1866.0
#            IBOVV50   PUT OPTION      IBOVE       R$     1220.0     1220.0
#            IBOVV68   PUT OPTION  IBOVE  FM       R$     4283.0     4283.0
#            IBOVV69   PUT OPTION  IBOVE  FM       R$     4539.0     4539.0
#            IBOVX10   PUT OPTION      IBOVE       R$    21000.0    21000.0
#
# ...

# %%
df['Exp'] = df['ExpiringDate'] - df.index.get_level_values('Date')

# %%
is_valid =
# Out:
#                      MarketType   FirmName  OpenPrice  HighPrice  LowPrice  \
# Date       Ticker
# 1996-07-15 OIB 6    CALL OPTION       IBOV     2850.0     3000.0    1700.0
#            OIB 8    CALL OPTION       IBOV     1400.0     1400.0     640.0
# 1996-07-16 OIB 5    CALL OPTION       IBOV     2600.0     2600.0    2600.0
#            OIB 6    CALL OPTION       IBOV     1700.0     1850.0    1200.0
#            OIB 8    CALL OPTION       IBOV      650.0      650.0     340.0
# ...                         ...        ...        ...        ...       ...
# 2020-04-22 IBOVT60   PUT OPTION      IBOVE     1732.0     1866.0    1732.0
#            IBOVV50   PUT OPTION      IBOVE     1220.0     1220.0    1210.0
#            IBOVV68   PUT OPTION  IBOVE  FM     4283.0     4283.0    4283.0
#            IBOVV69   PUT OPTION  IBOVE  FM     4539.0     4539.0    4539.0
#            IBOVX10   PUT OPTION      IBOVE    21000.0    21000.0   20500.0
#
# ...

# %%
df.FirmName.value_counts()
# Out:
# IBOVE        46625
# IBOVE FM     33696
# IBOV         26243
# IBOVE  FM    21466
# IBOV  FM      7907
# IBXLE           93
# MIBV            83
# IBXL             1
# Name: FirmName, dtype: int64

# %%
df=df.drop(['Currency','IsinCode'], axis=1)

# %%
df.Exp.value_counts()
# Out:
# 29 days     2036
# 28 days     1988
# 35 days     1967
# 34 days     1950
# 27 days     1894
#             ...
# 575 days       1
# 679 days       1
# 582 days       1
# 60 days        1
# 671 days       1
# Name: Exp, Length: 526, dtype: int64
